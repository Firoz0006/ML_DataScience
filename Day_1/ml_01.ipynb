# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df=sns.load_dataset('iris')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
model=LinearRegression()
x=df[['petal_width']]# x always 2d
y=df['sepal_width']
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[.2]])
# Out:
# C:\Users\91620\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.26655359])

# %%
model.intercept_
# Out:
# np.float64(3.3084255580651947)

# %%
#print the intercept and slope of the Regresion line
print('Intercept:',model.intercept_)
print('slope:',model.coef_)
# Out:
# Intercept: 3.3084255580651947
# slope: [-0.20935983]

# %%
model.predict([[5]])
# Out:
# C:\Users\91620\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.2616264])

# %%
y_pred=model.predict(x)

# %%
plt.scatter(x,y)

# %%
plt.plot(x,y_pred,color='red')

# %%
plt.plot(x,y_pred,color='red')
plt.plot(x,y,color='blue')

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8)

# %%
model =LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
plt.plot(x_test,y_pred,color='red')
plt.plot(x_test,y_test,color='blue')

# %%
plt.plot(x_test,y_pred,color='red')
plt.scatter(x,y,color='green')
plt.scatter(x_test,y_test,color='blue')

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
r2_score(y_test,y_pred)
# Out:
# 0.20729119170533916

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
print('R2 Score:', r2_score(y_test,y_pred))#
print('Mean absolute error:',mean_absolute_error(y_test,y_pred))
print('Mean square error:',mean_squared_error(y_test,y_pred))
# Out:
# R2 Score: 0.20729119170533916
# Mean absolute error: 0.3329685019866439
# Mean square error: 0.1879952978249027
